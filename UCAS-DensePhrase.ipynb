# %% [markdown]
# # DensePhrases Demo

# %% [markdown]
# <em>DensePhrases</em> 是一项由Korea University和Princeton University联合完成的，基于短语级的英文文本匹配（召回）模型，面向于NLP中“开放域问答”和“阅读理解”任务。其项目[论文](https://arxiv.org/abs/2012.12624)被收录于ACL2021，你也可以直接通过其[Github项目地址](https://github.com/princeton-nlp/DensePhrases)来了解此模型，或使用其面向维基百科(2018.12.20)数据所训练的[Demo](http://densephrases.korea.ac.kr)来切身体会。

# %% [markdown]
# #### 更新于
# **\*\*\*\*\* 2021.09.30 \*\*\*\*\***
#
# **\*\*\*\*\* by lilingwei（lilingwei20@mails.ucas.ac.cn）\*\*\*\*\***

# %% [markdown]
# ## 设置colab
# 首先需要设置使用GPU，点击上方工具栏‘Edit’，进入‘Notebook Settings’，将硬件设置为GPU
# 需要注意的是，每次使用GPU的时间一般不能超过24小时，使用得越多，每次获得的时间片越少
# 实验结束后记得切换回None再关闭Notebook

# %%
# Check your GPU here
# %tensorflow_version 2.x
import tensorflow as tf
if __name__ == '__main__':
  print(tf.test.gpu_device_name())
  with tf.device('/device:GPU:0'):
    print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0
# /device:GPU:0

# %% [markdown]
# 其次需要在此挂载Google Drive以保存实验文件，需要提前申请好Google账号，然后关联建立相关Google Drive
# 具体步骤为运行以下代码，点击显示的URL，登录Google账号，将验证码粘贴到提示的黑框空白处，回车即可

# %%
# Mount your google drive here
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 创建DensePhrases项目，并安装好所需工具包

# %%
# Install apex
# %cd /content/gdrive/MyDrive/
# !wget https://github.com/NVIDIA/apex/archive/refs/heads/master.zip
# !unzip master.zip
# %cd apex-master/
# !python setup.py install
# %cd ..
# Out:
# /content/gdrive/MyDrive
# --2021-10-08 11:05:21--  https://github.com/NVIDIA/apex/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/NVIDIA/apex/zip/refs/heads/master [following]
# --2021-10-08 11:05:21--  https://codeload.github.com/NVIDIA/apex/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip.1’
#
# master.zip.1            [ <=>                ] 861.65K  --.-KB/s    in 0.1s
#
# 2021-10-08 11:05:21 (6.82 MB/s) - ‘master.zip.1’ saved [882329]
#
# Archive:  master.zip
# 3ad9db2adb968c67dd509c5408eeca0884f6ab3f
#    creating: apex-master/
#   inflating: apex-master/.gitignore
#   inflating: apex-master/.gitmodules
#  extracting: apex-master/.nojekyll
#   inflating: apex-master/LICENSE
#   inflating: apex-master/README.md
#    creating: apex-master/apex/
#    creating: apex-master/apex/RNN/
#  extracting: apex-master/apex/RNN/README.md
#   inflating: apex-master/apex/RNN/RNNBackend.py
#   inflating: apex-master/apex/RNN/__init__.py
#   inflating: apex-master/apex/RNN/cells.py
#   inflating: apex-master/apex/RNN/models.py
#   inflating: apex-master/apex/__init__.py
#   inflating: apex-master/apex/_autocast_utils.py
#    creating: apex-master/apex/amp/
#   inflating: apex-master/apex/amp/README.md
#   inflating: apex-master/apex/amp/__init__.py
#   inflating: apex-master/apex/amp/__version__.py
#   inflating: apex-master/apex/amp/_amp_state.py
#   inflating: apex-master/apex/amp/_initialize.py
#   inflating: apex-master/apex/amp/_process_optimizer.py
#   inflating: apex-master/apex/amp/amp.py
#   inflating: apex-master/apex/amp/compat.py
#   inflating: apex-master/apex/amp/frontend.py
#   inflating: apex-master/apex/amp/handle.py
#    creating: apex-master/apex/amp/lists/
#  extracting: apex-master/apex/amp/lists/__init__.py
#   inflating: apex-master/apex/amp/lists/functional_overrides.py
#   inflating: apex-master/apex/amp/lists/tensor_overrides.py
#   inflating: apex-master/apex/amp/lists/torch_overrides.py
#   inflating: apex-master/apex/amp/opt.py
#   inflating: apex-master/apex/amp/rnn_compat.py
#   inflating: apex-master/apex/amp/scaler.py
#   inflating: apex-master/apex/amp/utils.py
#   inflating: apex-master/apex/amp/wrap.py
#    creating: apex-master/apex/contrib/
#  extracting: apex-master/apex/contrib/__init__.py
#    creating: apex-master/apex/contrib/bottleneck/
#   inflating: apex-master/apex/contrib/bottleneck/__init__.py
#   inflating: apex-master/apex/contrib/bottleneck/bottleneck.py
#   inflating: apex-master/apex/contrib/bottleneck/bottleneck_module_test.py
#   inflating: apex-master/apex/contrib/bottleneck/test.py
#    creating: apex-master/apex/contrib/csrc/
#    creating: apex-master/apex/contrib/csrc/bottleneck/
#   inflating: apex-master/apex/contrib/csrc/bottleneck/bottleneck.cpp
#    creating: apex-master/apex/contrib/csrc/cudnn-frontend/
#    creating: apex-master/apex/contrib/csrc/fmha/
#   inflating: apex-master/apex/contrib/csrc/fmha/fmha_api.cpp
#    creating: apex-master/apex/contrib/csrc/fmha/src/
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha.h
#    creating: apex-master/apex/contrib/csrc/fmha/src/fmha/
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/gemm.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/gmem_tile.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/kernel_traits.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/mask.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/smem_tile.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/softmax.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha/utils.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_dgrad_fp16_128_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_dgrad_fp16_256_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_dgrad_fp16_384_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_dgrad_fp16_512_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_dgrad_kernel_1xN_reload.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_dgrad_kernel_1xN_reload_nl.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_fp16_128_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_fp16_256_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_fp16_384_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_fp16_512_64_kernel.sm80.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_kernel_1xN.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_kernel_1xN_nl.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_fprop_kernel_1xN_reload_v.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_kernel.h
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_noloop_reduce.cu
#   inflating: apex-master/apex/contrib/csrc/fmha/src/fmha_utils.h
#    creating: apex-master/apex/contrib/csrc/groupbn/
#   inflating: apex-master/apex/contrib/csrc/groupbn/batch_norm.cu
#   inflating: apex-master/apex/contrib/csrc/groupbn/batch_norm.h
#   inflating: apex-master/apex/contrib/csrc/groupbn/batch_norm_add_relu.cu
#   inflating: apex-master/apex/contrib/csrc/groupbn/batch_norm_add_relu.h
#   inflating: apex-master/apex/contrib/csrc/groupbn/cuda_utils.h
#   inflating: apex-master/apex/contrib/csrc/groupbn/interface.cpp
#   inflating: apex-master/apex/contrib/csrc/groupbn/ipc.cu
#   inflating: apex-master/apex/contrib/csrc/groupbn/nhwc_batch_norm_kernel.h
#    creating: apex-master/apex/contrib/csrc/layer_norm/
#   inflating: apex-master/apex/contrib/csrc/layer_norm/ln_api.cpp
#   inflating: apex-master/apex/contrib/csrc/layer_norm/ln_bwd_semi_cuda_kernel.cu
#   inflating: apex-master/apex/contrib/csrc/layer_norm/ln_fwd_cuda_kernel.cu
#   inflating: apex-master/apex/contrib/csrc/layer_norm/ln_kernel_traits.h
#   inflating: apex-master/apex/contrib/csrc/layer_norm/utils.cuh
#    creating: apex-master/apex/contrib/csrc/multihead_attn/
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/additive_masked_softmax_dropout.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/additive_masked_softmax_dropout_cuda.cu
#    creating: apex-master/apex/contrib/csrc/multihead_attn/cutlass/
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/dropout.h
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/encdec_multihead_attn.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/encdec_multihead_attn_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/encdec_multihead_attn_norm_add.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/encdec_multihead_attn_norm_add_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/layer_norm.h
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/masked_softmax_dropout.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/masked_softmax_dropout_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/philox.h
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_bias.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_bias_additive_mask.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_bias_additive_mask_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_bias_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_norm_add.cpp
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/self_multihead_attn_norm_add_cuda.cu
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/softmax.h
#   inflating: apex-master/apex/contrib/csrc/multihead_attn/strided_batched_gemm.h
#    creating: apex-master/apex/contrib/csrc/optimizers/
#   inflating: apex-master/apex/contrib/csrc/optimizers/fused_adam_cuda.cpp
#   inflating: apex-master/apex/contrib/csrc/optimizers/fused_adam_cuda_kernel.cu
#   inflating: apex-master/apex/contrib/csrc/optimizers/fused_lamb_cuda.cpp
#   inflating: apex-master/apex/contrib/csrc/optimizers/fused_lamb_cuda_kernel.cu
#   inflating: apex-master/apex/contrib/csrc/optimizers/multi_tensor_distopt_adam.cpp
#   inflating: apex-master/apex/contrib/csrc/optimizers/multi_tensor_distopt_adam_kernel.cu
#   inflating: apex-master/apex/contrib/csrc/optimizers/multi_tensor_distopt_lamb.cpp
#   inflating: apex-master/apex/contrib/csrc/optimizers/multi_tensor_distopt_lamb_kernel.cu
#    creating: apex-master/apex/contrib/csrc/transducer/
#   inflating: apex-master/apex/contrib/csrc/transducer/transducer_joint.cpp
#   inflating: apex-master/apex/contrib/csrc/transducer/transducer_joint_kernel.cu
#   inflating: apex-master/apex/contrib/csrc/transducer/transducer_loss.cpp
#   inflating: apex-master/apex/contrib/csrc/transducer/transducer_loss_kernel.cu
#    creating: apex-master/apex/contrib/csrc/xentropy/
#   inflating: apex-master/apex/contrib/csrc/xentropy/interface.cpp
#   inflating: apex-master/apex/contrib/csrc/xentropy/xentropy_kernel.cu
#    creating: apex-master/apex/contrib/examples/
#    creating: apex-master/apex/contrib/examples/multihead_attn/
#   inflating: apex-master/apex/contrib/examples/multihead_attn/func_test_multihead_attn.py
#   inflating: apex-master/apex/contrib/examples/multihead_attn/perf_test_multihead_attn.py
#    creating: apex-master/apex/contrib/fmha/
#  extracting: apex-master/apex/contrib/fmha/__init__.py
#   inflating: apex-master/apex/contrib/fmha/fmha.py
#    creating: apex-master/apex/contrib/groupbn/
#   inflating: apex-master/apex/contrib/groupbn/__init__.py
#   inflating: apex-master/apex/contrib/groupbn/batch_norm.py
#    creating: apex-master/apex/contrib/layer_norm/
#   inflating: apex-master/apex/contrib/layer_norm/__init__.py
#   inflating: apex-master/apex/contrib/layer_norm/layer_norm.py
#    creating: apex-master/apex/contrib/multihead_attn/
#   inflating: apex-master/apex/contrib/multihead_attn/MHA_bwd.png
#   inflating: apex-master/apex/contrib/multihead_attn/MHA_fwd.png
#   inflating: apex-master/apex/contrib/multihead_attn/README.md
#   inflating: apex-master/apex/contrib/multihead_attn/__init__.py
#   inflating: apex-master/apex/contrib/multihead_attn/encdec_multihead_attn.py
#   inflating: apex-master/apex/contrib/multihead_attn/encdec_multihead_attn_func.py
#   inflating: apex-master/apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py
#   inflating: apex-master/apex/contrib/multihead_attn/fast_encdec_multihead_attn_norm_add_func.py
#   inflating: apex-master/apex/contrib/multihead_attn/fast_self_multihead_attn_func.py
#   inflating: apex-master/apex/contrib/multihead_attn/fast_self_multihead_attn_norm_add_func.py
#   inflating: apex-master/apex/contrib/multihead_attn/mask_softmax_dropout_func.py
#   inflating: apex-master/apex/contrib/multihead_attn/self_multihead_attn.py
#   inflating: apex-master/apex/contrib/multihead_attn/self_multihead_attn_func.py
#    creating: apex-master/apex/contrib/optimizers/
#   inflating: apex-master/apex/contrib/optimizers/__init__.py
#   inflating: apex-master/apex/contrib/optimizers/distributed_fused_adam.py
#   inflating: apex-master/apex/contrib/optimizers/distributed_fused_adam_v2.py
#   inflating: apex-master/apex/contrib/optimizers/distributed_fused_adam_v3.py
#   inflating: apex-master/apex/contrib/optimizers/distributed_fused_lamb.py
#   inflating: apex-master/apex/contrib/optimizers/fp16_optimizer.py
#   inflating: apex-master/apex/contrib/optimizers/fused_adam.py
#   inflating: apex-master/apex/contrib/optimizers/fused_lamb.py
#   inflating: apex-master/apex/contrib/optimizers/fused_sgd.py
#    creating: apex-master/apex/contrib/sparsity/
#   inflating: apex-master/apex/contrib/sparsity/README.md
#   inflating: apex-master/apex/contrib/sparsity/__init__.py
#   inflating: apex-master/apex/contrib/sparsity/asp.py
#   inflating: apex-master/apex/contrib/sparsity/sparse_masklib.py
#    creating: apex-master/apex/contrib/sparsity/test/
#   inflating: apex-master/apex/contrib/sparsity/test/checkpointing_test_part1.py
#   inflating: apex-master/apex/contrib/sparsity/test/checkpointing_test_part2.py
#   inflating: apex-master/apex/contrib/sparsity/test/checkpointing_test_reference.py
#   inflating: apex-master/apex/contrib/sparsity/test/toy_problem.py
#    creating: apex-master/apex/contrib/test/
#    creating: apex-master/apex/contrib/test/fmha/
#   inflating: apex-master/apex/contrib/test/fmha/test_fmha.py
#    creating: apex-master/apex/contrib/test/fused_dense/
#   inflating: apex-master/apex/contrib/test/fused_dense/test_fused_dense.py
#    creating: apex-master/apex/contrib/test/layer_norm/
#   inflating: apex-master/apex/contrib/test/layer_norm/test_fast_layer_norm.py
#    creating: apex-master/apex/contrib/test/multihead_attn/
#   inflating: apex-master/apex/contrib/test/multihead_attn/test_encdec_multihead_attn.py
#   inflating: apex-master/apex/contrib/test/multihead_attn/test_encdec_multihead_attn_norm_add.py
#   inflating: apex-master/apex/contrib/test/multihead_attn/test_fast_self_multihead_attn_bias.py
#   inflating: apex-master/apex/contrib/test/multihead_attn/test_mha_fused_softmax.py
#   inflating: apex-master/apex/contrib/test/multihead_attn/test_self_multihead_attn.py
#   inflating: apex-master/apex/contrib/test/multihead_attn/test_self_multihead_attn_norm_add.py
#   inflating: apex-master/apex/contrib/test/test_label_smoothing.py
#    creating: apex-master/apex/contrib/test/transducer/
#   inflating: apex-master/apex/contrib/test/transducer/test_transducer_joint.py
#   inflating: apex-master/apex/contrib/test/transducer/test_transducer_loss.py
#   inflating: apex-master/apex/contrib/test/transducer/transducer_ref.py
#    creating: apex-master/apex/contrib/transducer/
#   inflating: apex-master/apex/contrib/transducer/__init__.py
#   inflating: apex-master/apex/contrib/transducer/transducer.py
#    creating: apex-master/apex/contrib/xentropy/
#   inflating: apex-master/apex/contrib/xentropy/__init__.py
#   inflating: apex-master/apex/contrib/xentropy/softmax_xentropy.py
#    creating: apex-master/apex/fp16_utils/
#   inflating: apex-master/apex/fp16_utils/README.md
#   inflating: apex-master/apex/fp16_utils/__init__.py
#   inflating: apex-master/apex/fp16_utils/fp16_optimizer.py
#   inflating: apex-master/apex/fp16_utils/fp16util.py
#   inflating: apex-master/apex/fp16_utils/loss_scaler.py
#    creating: apex-master/apex/fused_dense/
#  extracting: apex-master/apex/fused_dense/__init__.py
#   inflating: apex-master/apex/fused_dense/fused_dense.py
#    creating: apex-master/apex/mlp/
#  extracting: apex-master/apex/mlp/__init__.py
#   inflating: apex-master/apex/mlp/mlp.py
#    creating: apex-master/apex/multi_tensor_apply/
#   inflating: apex-master/apex/multi_tensor_apply/__init__.py
#   inflating: apex-master/apex/multi_tensor_apply/multi_tensor_apply.py
#    creating: apex-master/apex/normalization/
#   inflating: apex-master/apex/normalization/__init__.py
#   inflating: apex-master/apex/normalization/fused_layer_norm.py
#    creating: apex-master/apex/optimizers/
#   inflating: apex-master/apex/optimizers/__init__.py
#   inflating: apex-master/apex/optimizers/fused_adagrad.py
#   inflating: apex-master/apex/optimizers/fused_adam.py
#   inflating: apex-master/apex/optimizers/fused_lamb.py
#   inflating: apex-master/apex/optimizers/fused_novograd.py
#   inflating: apex-master/apex/optimizers/fused_sgd.py
#    creating: apex-master/apex/parallel/
#   inflating: apex-master/apex/parallel/LARC.py
#   inflating: apex-master/apex/parallel/README.md
#   inflating: apex-master/apex/parallel/__init__.py
#   inflating: apex-master/apex/parallel/distributed.py
#   inflating: apex-master/apex/parallel/multiproc.py
#   inflating: apex-master/apex/parallel/optimized_sync_batchnorm.py
#   inflating: apex-master/apex/parallel/optimized_sync_batchnorm_kernel.py
#   inflating: apex-master/apex/parallel/sync_batchnorm.py
#   inflating: apex-master/apex/parallel/sync_batchnorm_kernel.py
#    creating: apex-master/apex/pyprof/
#   inflating: apex-master/apex/pyprof/FAQs.md
#   inflating: apex-master/apex/pyprof/README.md
#   inflating: apex-master/apex/pyprof/__init__.py
#    creating: apex-master/apex/pyprof/examples/
#   inflating: apex-master/apex/pyprof/examples/.gitignore
#    creating: apex-master/apex/pyprof/examples/apex/
#   inflating: apex-master/apex/pyprof/examples/apex/README.md
#   inflating: apex-master/apex/pyprof/examples/apex/fused_adam.py
#   inflating: apex-master/apex/pyprof/examples/apex/fused_layer_norm.py
#   inflating: apex-master/apex/pyprof/examples/apex/test.sh
#    creating: apex-master/apex/pyprof/examples/custom_func_module/
#   inflating: apex-master/apex/pyprof/examples/custom_func_module/README.md
#   inflating: apex-master/apex/pyprof/examples/custom_func_module/custom_function.py
#   inflating: apex-master/apex/pyprof/examples/custom_func_module/custom_module.py
#   inflating: apex-master/apex/pyprof/examples/custom_func_module/test.sh
#    creating: apex-master/apex/pyprof/examples/imagenet/
#   inflating: apex-master/apex/pyprof/examples/imagenet/imagenet.py
#   inflating: apex-master/apex/pyprof/examples/imagenet/test.sh
#    creating: apex-master/apex/pyprof/examples/jit/
#   inflating: apex-master/apex/pyprof/examples/jit/README.md
#   inflating: apex-master/apex/pyprof/examples/jit/jit_script_function.py
#   inflating: apex-master/apex/pyprof/examples/jit/jit_script_method.py
#   inflating: apex-master/apex/pyprof/examples/jit/jit_trace_function.py
#   inflating: apex-master/apex/pyprof/examples/jit/jit_trace_method.py
#   inflating: apex-master/apex/pyprof/examples/jit/test.sh
#   inflating: apex-master/apex/pyprof/examples/lenet.py
#   inflating: apex-master/apex/pyprof/examples/operators.py
#   inflating: apex-master/apex/pyprof/examples/simple.py
#    creating: apex-master/apex/pyprof/examples/user_annotation/
#   inflating: apex-master/apex/pyprof/examples/user_annotation/README.md
#   inflating: apex-master/apex/pyprof/examples/user_annotation/resnet.py
#   inflating: apex-master/apex/pyprof/examples/user_annotation/test.sh
#    creating: apex-master/apex/pyprof/nvtx/
#   inflating: apex-master/apex/pyprof/nvtx/__init__.py
#   inflating: apex-master/apex/pyprof/nvtx/nvmarker.py
#    creating: apex-master/apex/pyprof/parse/
#  extracting: apex-master/apex/pyprof/parse/__init__.py
#   inflating: apex-master/apex/pyprof/parse/__main__.py
#   inflating: apex-master/apex/pyprof/parse/db.py
#   inflating: apex-master/apex/pyprof/parse/kernel.py
#   inflating: apex-master/apex/pyprof/parse/nvvp.py
#   inflating: apex-master/apex/pyprof/parse/parse.py
#    creating: apex-master/apex/pyprof/prof/
#  extracting: apex-master/apex/pyprof/prof/__init__.py
#   inflating: apex-master/apex/pyprof/prof/__main__.py
#   inflating: apex-master/apex/pyprof/prof/activation.py
#   inflating: apex-master/apex/pyprof/prof/base.py
#   inflating: apex-master/apex/pyprof/prof/blas.py
#   inflating: apex-master/apex/pyprof/prof/conv.py
#   inflating: apex-master/apex/pyprof/prof/convert.py
#   inflating: apex-master/apex/pyprof/prof/data.py
#   inflating: apex-master/apex/pyprof/prof/dropout.py
#   inflating: apex-master/apex/pyprof/prof/embedding.py
#   inflating: apex-master/apex/pyprof/prof/index_slice_join_mutate.py
#   inflating: apex-master/apex/pyprof/prof/linear.py
#   inflating: apex-master/apex/pyprof/prof/loss.py
#   inflating: apex-master/apex/pyprof/prof/misc.py
#   inflating: apex-master/apex/pyprof/prof/normalization.py
#   inflating: apex-master/apex/pyprof/prof/optim.py
#   inflating: apex-master/apex/pyprof/prof/output.py
#   inflating: apex-master/apex/pyprof/prof/pointwise.py
#   inflating: apex-master/apex/pyprof/prof/pooling.py
#   inflating: apex-master/apex/pyprof/prof/prof.py
#   inflating: apex-master/apex/pyprof/prof/randomSample.py
#   inflating: apex-master/apex/pyprof/prof/recurrentCell.py
#   inflating: apex-master/apex/pyprof/prof/reduction.py
#   inflating: apex-master/apex/pyprof/prof/softmax.py
#   inflating: apex-master/apex/pyprof/prof/usage.py
#   inflating: apex-master/apex/pyprof/prof/utility.py
#    creating: apex-master/apex/reparameterization/
#  extracting: apex-master/apex/reparameterization/README.md
#   inflating: apex-master/apex/reparameterization/__init__.py
#   inflating: apex-master/apex/reparameterization/reparameterization.py
#   inflating: apex-master/apex/reparameterization/weight_norm.py
#    creating: apex-master/apex/transformer/
#   inflating: apex-master/apex/transformer/README.md
#   inflating: apex-master/apex/transformer/__init__.py
#   inflating: apex-master/apex/transformer/enums.py
#    creating: apex-master/apex/transformer/functional/
#   inflating: apex-master/apex/transformer/functional/__init__.py
#   inflating: apex-master/apex/transformer/functional/fused_softmax.py
#   inflating: apex-master/apex/transformer/parallel_state.py
#    creating: apex-master/apex/transformer/tensor_parallel/
#   inflating: apex-master/apex/transformer/tensor_parallel/__init__.py
#   inflating: apex-master/apex/transformer/tensor_parallel/cross_entropy.py
#   inflating: apex-master/apex/transformer/tensor_parallel/data.py
#   inflating: apex-master/apex/transformer/tensor_parallel/layers.py
#   inflating: apex-master/apex/transformer/tensor_parallel/mappings.py
#   inflating: apex-master/apex/transformer/tensor_parallel/memory.py
#   inflating: apex-master/apex/transformer/tensor_parallel/microbatches.py
#   inflating: apex-master/apex/transformer/tensor_parallel/random.py
#    creating: apex-master/apex/transformer/tensor_parallel/tests/
#  extracting: apex-master/apex/transformer/tensor_parallel/tests/__init__.py
#   inflating: apex-master/apex/transformer/tensor_parallel/tests/arguments.py
#   inflating: apex-master/apex/transformer/tensor_parallel/tests/commons.py
#   inflating: apex-master/apex/transformer/tensor_parallel/tests/global_vars.py
#   inflating: apex-master/apex/transformer/tensor_parallel/utils.py
#    creating: apex-master/csrc/
#   inflating: apex-master/csrc/amp_C_frontend.cpp
#   inflating: apex-master/csrc/compat.h
#   inflating: apex-master/csrc/flatten_unflatten.cpp
#   inflating: apex-master/csrc/fused_dense.cpp
#   inflating: apex-master/csrc/fused_dense_cuda.cu
#   inflating: apex-master/csrc/layer_norm_cuda.cpp
#   inflating: apex-master/csrc/layer_norm_cuda_kernel.cu
#    creating: apex-master/csrc/megatron/
#   inflating: apex-master/csrc/megatron/scaled_masked_softmax.cpp
#   inflating: apex-master/csrc/megatron/scaled_masked_softmax.h
#   inflating: apex-master/csrc/megatron/scaled_masked_softmax_cuda.cu
#   inflating: apex-master/csrc/megatron/scaled_upper_triang_masked_softmax.cpp
#   inflating: apex-master/csrc/megatron/scaled_upper_triang_masked_softmax.h
#   inflating: apex-master/csrc/megatron/scaled_upper_triang_masked_softmax_cuda.cu
#   inflating: apex-master/csrc/mlp.cpp
#   inflating: apex-master/csrc/mlp_cuda.cu
#   inflating: apex-master/csrc/multi_tensor_adagrad.cu
#   inflating: apex-master/csrc/multi_tensor_adam.cu
#   inflating: apex-master/csrc/multi_tensor_apply.cuh
#   inflating: apex-master/csrc/multi_tensor_axpby_kernel.cu
#   inflating: apex-master/csrc/multi_tensor_l2norm_kernel.cu
#   inflating: apex-master/csrc/multi_tensor_l2norm_scale_kernel.cu
#   inflating: apex-master/csrc/multi_tensor_lamb.cu
#   inflating: apex-master/csrc/multi_tensor_lamb_stage_1.cu
#   inflating: apex-master/csrc/multi_tensor_lamb_stage_2.cu
#   inflating: apex-master/csrc/multi_tensor_novograd.cu
#   inflating: apex-master/csrc/multi_tensor_scale_kernel.cu
#   inflating: apex-master/csrc/multi_tensor_sgd_kernel.cu
#   inflating: apex-master/csrc/syncbn.cpp
#   inflating: apex-master/csrc/type_shim.h
#   inflating: apex-master/csrc/welford.cu
#    creating: apex-master/docs/
#   inflating: apex-master/docs/Makefile
#    creating: apex-master/docs/source/
#    creating: apex-master/docs/source/_static/
#    creating: apex-master/docs/source/_static/css/
#   inflating: apex-master/docs/source/_static/css/pytorch_theme.css
#    creating: apex-master/docs/source/_static/img/
#   inflating: apex-master/docs/source/_static/img/nv-pytorch2.png
#    creating: apex-master/docs/source/_templates/
#   inflating: apex-master/docs/source/_templates/layout.html
#   inflating: apex-master/docs/source/advanced.rst
#   inflating: apex-master/docs/source/amp.rst
#   inflating: apex-master/docs/source/conf.py
#   inflating: apex-master/docs/source/fp16_utils.rst
#   inflating: apex-master/docs/source/index.rst
#   inflating: apex-master/docs/source/layernorm.rst
#   inflating: apex-master/docs/source/optimizers.rst
#   inflating: apex-master/docs/source/parallel.rst
#    creating: apex-master/examples/
#   inflating: apex-master/examples/README.md
#    creating: apex-master/examples/dcgan/
#   inflating: apex-master/examples/dcgan/README.md
#   inflating: apex-master/examples/dcgan/main_amp.py
#    creating: apex-master/examples/docker/
#   inflating: apex-master/examples/docker/Dockerfile
#   inflating: apex-master/examples/docker/README.md
#    creating: apex-master/examples/imagenet/
#   inflating: apex-master/examples/imagenet/README.md
#   inflating: apex-master/examples/imagenet/main_amp.py
#    creating: apex-master/examples/simple/
#    creating: apex-master/examples/simple/distributed/
#   inflating: apex-master/examples/simple/distributed/README.md
#   inflating: apex-master/examples/simple/distributed/distributed_data_parallel.py
#   inflating: apex-master/examples/simple/distributed/run.sh
#   inflating: apex-master/requirements.txt
#   inflating: apex-master/requirements_dev.txt
#   inflating: apex-master/setup.py
#    creating: apex-master/tests/
#    creating: apex-master/tests/L0/
#    creating: apex-master/tests/L0/run_amp/
#  extracting: apex-master/tests/L0/run_amp/__init__.py
#   inflating: apex-master/tests/L0/run_amp/test_add_param_group.py
#   inflating: apex-master/tests/L0/run_amp/test_basic_casts.py
#   inflating: apex-master/tests/L0/run_amp/test_cache.py
#   inflating: apex-master/tests/L0/run_amp/test_checkpointing.py
#   inflating: apex-master/tests/L0/run_amp/test_fused_sgd.py
#   inflating: apex-master/tests/L0/run_amp/test_larc.py
#   inflating: apex-master/tests/L0/run_amp/test_multi_tensor_axpby.py
#   inflating: apex-master/tests/L0/run_amp/test_multi_tensor_l2norm.py
#   inflating: apex-master/tests/L0/run_amp/test_multi_tensor_scale.py
#   inflating: apex-master/tests/L0/run_amp/test_multiple_models_optimizers_losses.py
#   inflating: apex-master/tests/L0/run_amp/test_promotion.py
#   inflating: apex-master/tests/L0/run_amp/test_rnn.py
#   inflating: apex-master/tests/L0/run_amp/utils.py
#    creating: apex-master/tests/L0/run_fp16util/
#  extracting: apex-master/tests/L0/run_fp16util/__init__.py
#   inflating: apex-master/tests/L0/run_fp16util/test_fp16util.py
#    creating: apex-master/tests/L0/run_fused_layer_norm/
#   inflating: apex-master/tests/L0/run_fused_layer_norm/test_fused_layer_norm.py
#    creating: apex-master/tests/L0/run_mlp/
#   inflating: apex-master/tests/L0/run_mlp/test_mlp.py
#    creating: apex-master/tests/L0/run_optimizers/
#  extracting: apex-master/tests/L0/run_optimizers/__init__.py
#   inflating: apex-master/tests/L0/run_optimizers/test_dist_adam.py
#   inflating: apex-master/tests/L0/run_optimizers/test_fused_novograd.py
#   inflating: apex-master/tests/L0/run_optimizers/test_fused_optimizer.py
#   inflating: apex-master/tests/L0/run_optimizers/test_lamb.py
#    creating: apex-master/tests/L0/run_pyprof_data/
#  extracting: apex-master/tests/L0/run_pyprof_data/__init__.py
#   inflating: apex-master/tests/L0/run_pyprof_data/test_pyprof_data.py
#    creating: apex-master/tests/L0/run_pyprof_nvtx/
#   inflating: apex-master/tests/L0/run_pyprof_nvtx/__init__.py
#   inflating: apex-master/tests/L0/run_pyprof_nvtx/test_pyprof_nvtx.py
#   inflating: apex-master/tests/L0/run_test.py
#    creating: apex-master/tests/L0/run_transformer/
#  extracting: apex-master/tests/L0/run_transformer/__init__.py
#   inflating: apex-master/tests/L0/run_transformer/run_cross_entropy_test.py
#   inflating: apex-master/tests/L0/run_transformer/run_data_test.py
#   inflating: apex-master/tests/L0/run_transformer/run_initialize_test.py
#   inflating: apex-master/tests/L0/run_transformer/run_layers_test.py
#   inflating: apex-master/tests/L0/run_transformer/run_mappings_test.py
#   inflating: apex-master/tests/L0/run_transformer/run_random_test.py
#   inflating: apex-master/tests/L0/run_transformer/run_utils_test.py
#   inflating: apex-master/tests/L0/run_transformer/test_fused_softmax.py
#   inflating: apex-master/tests/L0/run_transformer/test_mpu.py
#    creating: apex-master/tests/L1/
#    creating: apex-master/tests/L1/common/
#   inflating: apex-master/tests/L1/common/compare.py
#   inflating: apex-master/tests/L1/common/main_amp.py
#   inflating: apex-master/tests/L1/common/run_test.sh
#    creating: apex-master/tests/L1/cross_product/
#   inflating: apex-master/tests/L1/cross_product/run.sh
#    creating: apex-master/tests/L1/cross_product_distributed/
#   inflating: apex-master/tests/L1/cross_product_distributed/run.sh
#    creating: apex-master/tests/distributed/
#    creating: apex-master/tests/distributed/DDP/
#   inflating: apex-master/tests/distributed/DDP/ddp_race_condition_test.py
#   inflating: apex-master/tests/distributed/DDP/run_race_test.sh
#    creating: apex-master/tests/distributed/amp_master_params/
#   inflating: apex-master/tests/distributed/amp_master_params/amp_master_params.py
#   inflating: apex-master/tests/distributed/amp_master_params/compare.py
#   inflating: apex-master/tests/distributed/amp_master_params/run.sh
#    creating: apex-master/tests/distributed/synced_batchnorm/
#   inflating: apex-master/tests/distributed/synced_batchnorm/python_single_gpu_unit_test.py
#   inflating: apex-master/tests/distributed/synced_batchnorm/single_gpu_unit_test.py
#   inflating: apex-master/tests/distributed/synced_batchnorm/test_batchnorm1d.py
#   inflating: apex-master/tests/distributed/synced_batchnorm/test_groups.py
#   inflating: apex-master/tests/distributed/synced_batchnorm/two_gpu_test_different_batch_size.py
#   inflating: apex-master/tests/distributed/synced_batchnorm/two_gpu_unit_test.py
#   inflating: apex-master/tests/distributed/synced_batchnorm/unit_test.sh
#    creating: apex-master/tests/docker_extension_builds/
#   inflating: apex-master/tests/docker_extension_builds/run.sh
# /content/gdrive/My Drive/apex-master
#
#
# torch.__version__  = 1.7.1
#
#
# setup.py:67: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#   warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
# running install
# running bdist_egg
# running egg_info
# creating apex.egg-info
# writing apex.egg-info/PKG-INFO
# writing dependency_links to apex.egg-info/dependency_links.txt
# writing top-level names to apex.egg-info/top_level.txt
# writing manifest file 'apex.egg-info/SOURCES.txt'
# reading manifest file 'apex.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'apex.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/apex
# copying apex/__init__.py -> build/lib/apex
# copying apex/_autocast_utils.py -> build/lib/apex
# creating build/lib/apex/RNN
# copying apex/RNN/RNNBackend.py -> build/lib/apex/RNN
# copying apex/RNN/__init__.py -> build/lib/apex/RNN
# copying apex/RNN/cells.py -> build/lib/apex/RNN
# copying apex/RNN/models.py -> build/lib/apex/RNN
# creating build/lib/apex/amp
# copying apex/amp/__init__.py -> build/lib/apex/amp
# copying apex/amp/__version__.py -> build/lib/apex/amp
# copying apex/amp/_amp_state.py -> build/lib/apex/amp
# copying apex/amp/_initialize.py -> build/lib/apex/amp
# copying apex/amp/_process_optimizer.py -> build/lib/apex/amp
# copying apex/amp/amp.py -> build/lib/apex/amp
# copying apex/amp/compat.py -> build/lib/apex/amp
# copying apex/amp/frontend.py -> build/lib/apex/amp
# copying apex/amp/handle.py -> build/lib/apex/amp
# copying apex/amp/opt.py -> build/lib/apex/amp
# copying apex/amp/rnn_compat.py -> build/lib/apex/amp
# copying apex/amp/scaler.py -> build/lib/apex/amp
# copying apex/amp/utils.py -> build/lib/apex/amp
# copying apex/amp/wrap.py -> build/lib/apex/amp
# creating build/lib/apex/contrib
# copying apex/contrib/__init__.py -> build/lib/apex/contrib
# creating build/lib/apex/fp16_utils
# copying apex/fp16_utils/__init__.py -> build/lib/apex/fp16_utils
# copying apex/fp16_utils/fp16_optimizer.py -> build/lib/apex/fp16_utils
# copying apex/fp16_utils/fp16util.py -> build/lib/apex/fp16_utils
# copying apex/fp16_utils/loss_scaler.py -> build/lib/apex/fp16_utils
# creating build/lib/apex/fused_dense
# copying apex/fused_dense/__init__.py -> build/lib/apex/fused_dense
# copying apex/fused_dense/fused_dense.py -> build/lib/apex/fused_dense
# creating build/lib/apex/mlp
# copying apex/mlp/__init__.py -> build/lib/apex/mlp
# copying apex/mlp/mlp.py -> build/lib/apex/mlp
# creating build/lib/apex/multi_tensor_apply
# copying apex/multi_tensor_apply/__init__.py -> build/lib/apex/multi_tensor_apply
# copying apex/multi_tensor_apply/multi_tensor_apply.py -> build/lib/apex/multi_tensor_apply
# creating build/lib/apex/normalization
# copying apex/normalization/__init__.py -> build/lib/apex/normalization
# copying apex/normalization/fused_layer_norm.py -> build/lib/apex/normalization
# creating build/lib/apex/optimizers
# copying apex/optimizers/__init__.py -> build/lib/apex/optimizers
# copying apex/optimizers/fused_adagrad.py -> build/lib/apex/optimizers
# copying apex/optimizers/fused_adam.py -> build/lib/apex/optimizers
# copying apex/optimizers/fused_lamb.py -> build/lib/apex/optimizers
# copying apex/optimizers/fused_novograd.py -> build/lib/apex/optimizers
# copying apex/optimizers/fused_sgd.py -> build/lib/apex/optimizers
# creating build/lib/apex/parallel
# copying apex/parallel/LARC.py -> build/lib/apex/parallel
# copying apex/parallel/__init__.py -> build/lib/apex/parallel
# copying apex/parallel/distributed.py -> build/lib/apex/parallel
# copying apex/parallel/multiproc.py -> build/lib/apex/parallel
# copying apex/parallel/optimized_sync_batchnorm.py -> build/lib/apex/parallel
# copying apex/parallel/optimized_sync_batchnorm_kernel.py -> build/lib/apex/parallel
# copying apex/parallel/sync_batchnorm.py -> build/lib/apex/parallel
# copying apex/parallel/sync_batchnorm_kernel.py -> build/lib/apex/parallel
# creating build/lib/apex/pyprof
# copying apex/pyprof/__init__.py -> build/lib/apex/pyprof
# creating build/lib/apex/reparameterization
# copying apex/reparameterization/__init__.py -> build/lib/apex/reparameterization
# copying apex/reparameterization/reparameterization.py -> build/lib/apex/reparameterization
# copying apex/reparameterization/weight_norm.py -> build/lib/apex/reparameterization
# creating build/lib/apex/transformer
# copying apex/transformer/__init__.py -> build/lib/apex/transformer
# copying apex/transformer/enums.py -> build/lib/apex/transformer
# copying apex/transformer/parallel_state.py -> build/lib/apex/transformer
# creating build/lib/apex/amp/lists
# copying apex/amp/lists/__init__.py -> build/lib/apex/amp/lists
# copying apex/amp/lists/functional_overrides.py -> build/lib/apex/amp/lists
# copying apex/amp/lists/tensor_overrides.py -> build/lib/apex/amp/lists
# copying apex/amp/lists/torch_overrides.py -> build/lib/apex/amp/lists
# creating build/lib/apex/contrib/bottleneck
# copying apex/contrib/bottleneck/__init__.py -> build/lib/apex/contrib/bottleneck
# copying apex/contrib/bottleneck/bottleneck.py -> build/lib/apex/contrib/bottleneck
# copying apex/contrib/bottleneck/bottleneck_module_test.py -> build/lib/apex/contrib/bottleneck
# copying apex/contrib/bottleneck/test.py -> build/lib/apex/contrib/bottleneck
# creating build/lib/apex/contrib/fmha
# copying apex/contrib/fmha/__init__.py -> build/lib/apex/contrib/fmha
# copying apex/contrib/fmha/fmha.py -> build/lib/apex/contrib/fmha
# creating build/lib/apex/contrib/groupbn
# copying apex/contrib/groupbn/__init__.py -> build/lib/apex/contrib/groupbn
# copying apex/contrib/groupbn/batch_norm.py -> build/lib/apex/contrib/groupbn
# creating build/lib/apex/contrib/layer_norm
# copying apex/contrib/layer_norm/__init__.py -> build/lib/apex/contrib/layer_norm
# copying apex/contrib/layer_norm/layer_norm.py -> build/lib/apex/contrib/layer_norm
# creating build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/__init__.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/encdec_multihead_attn.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/encdec_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/fast_encdec_multihead_attn_norm_add_func.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/fast_self_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/fast_self_multihead_attn_norm_add_func.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/mask_softmax_dropout_func.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/self_multihead_attn.py -> build/lib/apex/contrib/multihead_attn
# copying apex/contrib/multihead_attn/self_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
# creating build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/__init__.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/distributed_fused_adam.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/distributed_fused_adam_v2.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/distributed_fused_adam_v3.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/distributed_fused_lamb.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/fp16_optimizer.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/fused_adam.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/fused_lamb.py -> build/lib/apex/contrib/optimizers
# copying apex/contrib/optimizers/fused_sgd.py -> build/lib/apex/contrib/optimizers
# creating build/lib/apex/contrib/sparsity
# copying apex/contrib/sparsity/__init__.py -> build/lib/apex/contrib/sparsity
# copying apex/contrib/sparsity/asp.py -> build/lib/apex/contrib/sparsity
# copying apex/contrib/sparsity/sparse_masklib.py -> build/lib/apex/contrib/sparsity
# creating build/lib/apex/contrib/transducer
# copying apex/contrib/transducer/__init__.py -> build/lib/apex/contrib/transducer
# copying apex/contrib/transducer/transducer.py -> build/lib/apex/contrib/transducer
# creating build/lib/apex/contrib/xentropy
# copying apex/contrib/xentropy/__init__.py -> build/lib/apex/contrib/xentropy
# copying apex/contrib/xentropy/softmax_xentropy.py -> build/lib/apex/contrib/xentropy
# creating build/lib/apex/pyprof/nvtx
# copying apex/pyprof/nvtx/__init__.py -> build/lib/apex/pyprof/nvtx
# copying apex/pyprof/nvtx/nvmarker.py -> build/lib/apex/pyprof/nvtx
# creating build/lib/apex/pyprof/parse
# copying apex/pyprof/parse/__init__.py -> build/lib/apex/pyprof/parse
# copying apex/pyprof/parse/__main__.py -> build/lib/apex/pyprof/parse
# copying apex/pyprof/parse/db.py -> build/lib/apex/pyprof/parse
# copying apex/pyprof/parse/kernel.py -> build/lib/apex/pyprof/parse
# copying apex/pyprof/parse/nvvp.py -> build/lib/apex/pyprof/parse
# copying apex/pyprof/parse/parse.py -> build/lib/apex/pyprof/parse
# creating build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/__init__.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/__main__.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/activation.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/base.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/blas.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/conv.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/convert.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/data.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/dropout.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/embedding.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/index_slice_join_mutate.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/linear.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/loss.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/misc.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/normalization.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/optim.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/output.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/pointwise.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/pooling.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/prof.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/randomSample.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/recurrentCell.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/reduction.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/softmax.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/usage.py -> build/lib/apex/pyprof/prof
# copying apex/pyprof/prof/utility.py -> build/lib/apex/pyprof/prof
# creating build/lib/apex/transformer/functional
# copying apex/transformer/functional/__init__.py -> build/lib/apex/transformer/functional
# copying apex/transformer/functional/fused_softmax.py -> build/lib/apex/transformer/functional
# creating build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/__init__.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/cross_entropy.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/data.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/layers.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/mappings.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/memory.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/microbatches.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/random.py -> build/lib/apex/transformer/tensor_parallel
# copying apex/transformer/tensor_parallel/utils.py -> build/lib/apex/transformer/tensor_parallel
# creating build/lib/apex/transformer/tensor_parallel/tests
# copying apex/transformer/tensor_parallel/tests/__init__.py -> build/lib/apex/transformer/tensor_parallel/tests
# copying apex/transformer/tensor_parallel/tests/arguments.py -> build/lib/apex/transformer/tensor_parallel/tests
# copying apex/transformer/tensor_parallel/tests/commons.py -> build/lib/apex/transformer/tensor_parallel/tests
# copying apex/transformer/tensor_parallel/tests/global_vars.py -> build/lib/apex/transformer/tensor_parallel/tests
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/apex
# copying build/lib/apex/__init__.py -> build/bdist.linux-x86_64/egg/apex
# copying build/lib/apex/_autocast_utils.py -> build/bdist.linux-x86_64/egg/apex
# creating build/bdist.linux-x86_64/egg/apex/RNN
# copying build/lib/apex/RNN/RNNBackend.py -> build/bdist.linux-x86_64/egg/apex/RNN
# copying build/lib/apex/RNN/__init__.py -> build/bdist.linux-x86_64/egg/apex/RNN
# copying build/lib/apex/RNN/cells.py -> build/bdist.linux-x86_64/egg/apex/RNN
# copying build/lib/apex/RNN/models.py -> build/bdist.linux-x86_64/egg/apex/RNN
# creating build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/__init__.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/__version__.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/_amp_state.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/_initialize.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/_process_optimizer.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/amp.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/compat.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/frontend.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/handle.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/opt.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/rnn_compat.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/scaler.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/utils.py -> build/bdist.linux-x86_64/egg/apex/amp
# copying build/lib/apex/amp/wrap.py -> build/bdist.linux-x86_64/egg/apex/amp
# creating build/bdist.linux-x86_64/egg/apex/amp/lists
# copying build/lib/apex/amp/lists/__init__.py -> build/bdist.linux-x86_64/egg/apex/amp/lists
# copying build/lib/apex/amp/lists/functional_overrides.py -> build/bdist.linux-x86_64/egg/apex/amp/lists
# copying build/lib/apex/amp/lists/tensor_overrides.py -> build/bdist.linux-x86_64/egg/apex/amp/lists
# copying build/lib/apex/amp/lists/torch_overrides.py -> build/bdist.linux-x86_64/egg/apex/amp/lists
# creating build/bdist.linux-x86_64/egg/apex/contrib
# copying build/lib/apex/contrib/__init__.py -> build/bdist.linux-x86_64/egg/apex/contrib
# creating build/bdist.linux-x86_64/egg/apex/contrib/bottleneck
# copying build/lib/apex/contrib/bottleneck/__init__.py -> build/bdist.linux-x86_64/egg/apex/contrib/bottleneck
# copying build/lib/apex/contrib/bottleneck/bottleneck.py -> build/bdist.linux-x86_64/egg/apex/contrib/bottleneck
# copying build/lib/apex/contrib/bottleneck/bottleneck_module_test.py -> build/bdist.linux-x86_64/egg/apex/contrib/bottleneck
# copying build/lib/apex/contrib/bottleneck/test.py -> build/bdist.linux-x86_64/egg/apex/contrib/bottleneck
# creating build/bdist.linux-x86_64/egg/apex/contrib/fmha
# copying build/lib/apex/contrib/fmha/__init__.py -> build/bdist.linux-x86_64/egg/apex/contrib/fmha
# copying build/lib/apex/contrib/fmha/fmha.py -> build/bdist.linux-x86_64/egg/apex/contrib/fmha
# creating build/bdist.linux-x86_64/egg/apex/contrib/groupbn
# copying build/lib/apex/contrib/groupbn/__init__.py -> build/bdist.linux-x86_64/egg/apex/contrib/groupbn
# copying build/lib/apex/contrib/groupbn/batch_norm.py -> build/bdist.linux-x86_64/egg/apex/contrib/groupbn
# creating build/bdist.linux-x86_64/egg/apex/contrib/layer_norm
# copying build/lib/apex/contrib/layer_norm/__init__.py -> build/bdist.linux-x86_64/egg/apex/contrib/layer_norm
# copying build/lib/apex/contrib/layer_norm/layer_norm.py -> build/bdist.linux-x86_64/egg/apex/contrib/layer_norm
# creating build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn
# copying build/lib/apex/contrib/multihead_attn/__init__.py -> build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn
# copying build/lib/apex/contrib/multihead_attn/encdec_multihead_attn.py -> build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn
# copying build/lib/apex/contrib/multihead_attn/encdec_multihead_attn_func.py -> build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn
# copying build/lib/apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py -> build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn
# ...
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/_amp_state.py to _amp_state.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/_initialize.py to _initialize.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/_process_optimizer.py to _process_optimizer.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/amp.py to amp.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/compat.py to compat.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/frontend.py to frontend.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/handle.py to handle.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/opt.py to opt.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/rnn_compat.py to rnn_compat.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/scaler.py to scaler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/wrap.py to wrap.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/lists/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/lists/functional_overrides.py to functional_overrides.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/lists/tensor_overrides.py to tensor_overrides.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/amp/lists/torch_overrides.py to torch_overrides.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/bottleneck/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/bottleneck/bottleneck.py to bottleneck.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/bottleneck/bottleneck_module_test.py to bottleneck_module_test.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/bottleneck/test.py to test.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/fmha/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/fmha/fmha.py to fmha.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/groupbn/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/groupbn/batch_norm.py to batch_norm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/layer_norm/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/layer_norm/layer_norm.py to layer_norm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/encdec_multihead_attn.py to encdec_multihead_attn.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/encdec_multihead_attn_func.py to encdec_multihead_attn_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py to fast_encdec_multihead_attn_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/fast_encdec_multihead_attn_norm_add_func.py to fast_encdec_multihead_attn_norm_add_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/fast_self_multihead_attn_func.py to fast_self_multihead_attn_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/fast_self_multihead_attn_norm_add_func.py to fast_self_multihead_attn_norm_add_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/mask_softmax_dropout_func.py to mask_softmax_dropout_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/self_multihead_attn.py to self_multihead_attn.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/multihead_attn/self_multihead_attn_func.py to self_multihead_attn_func.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/distributed_fused_adam.py to distributed_fused_adam.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/distributed_fused_adam_v2.py to distributed_fused_adam_v2.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/distributed_fused_adam_v3.py to distributed_fused_adam_v3.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/distributed_fused_lamb.py to distributed_fused_lamb.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/fp16_optimizer.py to fp16_optimizer.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/fused_adam.py to fused_adam.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/fused_lamb.py to fused_lamb.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/optimizers/fused_sgd.py to fused_sgd.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/sparsity/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/sparsity/asp.py to asp.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/sparsity/sparse_masklib.py to sparse_masklib.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/transducer/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/transducer/transducer.py to transducer.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/xentropy/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/contrib/xentropy/softmax_xentropy.py to softmax_xentropy.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/fp16_utils/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/fp16_utils/fp16_optimizer.py to fp16_optimizer.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/fp16_utils/fp16util.py to fp16util.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/fp16_utils/loss_scaler.py to loss_scaler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/fused_dense/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/fused_dense/fused_dense.py to fused_dense.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/mlp/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/mlp/mlp.py to mlp.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/multi_tensor_apply/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/multi_tensor_apply/multi_tensor_apply.py to multi_tensor_apply.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/normalization/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/normalization/fused_layer_norm.py to fused_layer_norm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/optimizers/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/optimizers/fused_adagrad.py to fused_adagrad.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/optimizers/fused_adam.py to fused_adam.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/optimizers/fused_lamb.py to fused_lamb.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/optimizers/fused_novograd.py to fused_novograd.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/optimizers/fused_sgd.py to fused_sgd.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/LARC.py to LARC.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/distributed.py to distributed.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/multiproc.py to multiproc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/optimized_sync_batchnorm.py to optimized_sync_batchnorm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/optimized_sync_batchnorm_kernel.py to optimized_sync_batchnorm_kernel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/sync_batchnorm.py to sync_batchnorm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/parallel/sync_batchnorm_kernel.py to sync_batchnorm_kernel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/nvtx/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/nvtx/nvmarker.py to nvmarker.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/parse/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/parse/__main__.py to __main__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/parse/db.py to db.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/parse/kernel.py to kernel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/parse/nvvp.py to nvvp.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/parse/parse.py to parse.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/__main__.py to __main__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/activation.py to activation.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/base.py to base.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/blas.py to blas.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/conv.py to conv.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/convert.py to convert.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/data.py to data.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/dropout.py to dropout.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/embedding.py to embedding.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/index_slice_join_mutate.py to index_slice_join_mutate.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/linear.py to linear.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/loss.py to loss.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/misc.py to misc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/normalization.py to normalization.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/optim.py to optim.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/output.py to output.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/pointwise.py to pointwise.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/pooling.py to pooling.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/prof.py to prof.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/randomSample.py to randomSample.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/recurrentCell.py to recurrentCell.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/reduction.py to reduction.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/softmax.py to softmax.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/usage.py to usage.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/pyprof/prof/utility.py to utility.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/reparameterization/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/reparameterization/reparameterization.py to reparameterization.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/reparameterization/weight_norm.py to weight_norm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/enums.py to enums.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/parallel_state.py to parallel_state.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/functional/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/functional/fused_softmax.py to fused_softmax.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/cross_entropy.py to cross_entropy.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/data.py to data.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/layers.py to layers.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/mappings.py to mappings.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/memory.py to memory.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/microbatches.py to microbatches.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/random.py to random.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/tests/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/tests/arguments.py to arguments.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/tests/commons.py to commons.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/apex/transformer/tensor_parallel/tests/global_vars.py to global_vars.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying apex.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying apex.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying apex.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying apex.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# apex.pyprof.nvtx.__pycache__.nvmarker.cpython-37: module references __file__
# apex.pyprof.nvtx.__pycache__.nvmarker.cpython-37: module references __path__
# creating dist
# creating 'dist/apex-0.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing apex-0.1-py3.7.egg
# removing '/usr/local/lib/python3.7/dist-packages/apex-0.1-py3.7.egg' (and everything under it)
# creating /usr/local/lib/python3.7/dist-packages/apex-0.1-py3.7.egg
# Extracting apex-0.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# apex 0.1 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.7/dist-packages/apex-0.1-py3.7.egg
# Processing dependencies for apex==0.1
# Finished processing dependencies for apex==0.1
# /content/gdrive/My Drive

# %%
# Install densephrases for course of UCAS
# !wget https://github.com/blackli7/DensePhrases/archive/refs/heads/main.zip
# !unzip main.zip
# Install other toolkits
# %cd DensePhrases-main
# !pip install -r requirements.txt
# !python setup.py develop
# Out:
# --2021-10-08 11:20:54--  https://github.com/blackli7/DensePhrases/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/blackli7/DensePhrases/zip/refs/heads/main [following]
# --2021-10-08 11:20:54--  https://codeload.github.com/blackli7/DensePhrases/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [        <=>         ]  43.62M  5.62MB/s    in 7.8s
#
# 2021-10-08 11:21:02 (5.62 MB/s) - ‘main.zip’ saved [45745017]
#
# Archive:  main.zip
# a5a8b2c364306d94155839346671affb387bc4a1
#    creating: DensePhrases-main/
#   inflating: DensePhrases-main/.DS_Store
#   inflating: DensePhrases-main/LICENSE
#   inflating: DensePhrases-main/Makefile
#   inflating: DensePhrases-main/README.md
#   inflating: DensePhrases-main/build_phrase_index.py
#   inflating: DensePhrases-main/config.sh
#    creating: DensePhrases-main/data/
#   inflating: DensePhrases-main/data/wiki_physics.json
#    creating: DensePhrases-main/data_process/
#   inflating: DensePhrases-main/data_process/data_process.py
#   inflating: DensePhrases-main/data_process/phdefinitions.html
#   inflating: DensePhrases-main/data_process/phdefinitions2.html
#   inflating: DensePhrases-main/data_process/wiki_physics.json
#    creating: DensePhrases-main/densephrases-data/
#    creating: DensePhrases-main/densephrases-data/truecase/
#   inflating: DensePhrases-main/densephrases-data/truecase/english_with_questions.dist
#    creating: DensePhrases-main/densephrases/
#  extracting: DensePhrases-main/densephrases/__init__.py
#    creating: DensePhrases-main/densephrases/demo/
#  extracting: DensePhrases-main/densephrases/demo/__init__.py
#    creating: DensePhrases-main/densephrases/demo/static/
#   inflating: DensePhrases-main/densephrases/demo/static/examples.txt
#   inflating: DensePhrases-main/densephrases/demo/static/examples_context.txt
#    creating: DensePhrases-main/densephrases/demo/static/files/
#   inflating: DensePhrases-main/densephrases/demo/static/files/all.js
#   inflating: DensePhrases-main/densephrases/demo/static/files/bootstrap.min.js
#   inflating: DensePhrases-main/densephrases/demo/static/files/favicon.ico
#   inflating: DensePhrases-main/densephrases/demo/static/files/jquery-3.3.1.min.js
#   inflating: DensePhrases-main/densephrases/demo/static/files/overview_new.png
#   inflating: DensePhrases-main/densephrases/demo/static/files/plogo.png
#   inflating: DensePhrases-main/densephrases/demo/static/files/popper.min.js
#   inflating: DensePhrases-main/densephrases/demo/static/files/preview.gif
#   inflating: DensePhrases-main/densephrases/demo/static/files/steps.png
#   inflating: DensePhrases-main/densephrases/demo/static/files/style.css
#   inflating: DensePhrases-main/densephrases/demo/static/index.html
#   inflating: DensePhrases-main/densephrases/demo/static/index_single.html
#    creating: DensePhrases-main/densephrases/models/
#   inflating: DensePhrases-main/densephrases/models/__init__.py
#   inflating: DensePhrases-main/densephrases/models/encoder.py
#   inflating: DensePhrases-main/densephrases/models/index.py
#    creating: DensePhrases-main/densephrases/utils/
#  extracting: DensePhrases-main/densephrases/utils/__init__.py
#   inflating: DensePhrases-main/densephrases/utils/data_utils.py
#   inflating: DensePhrases-main/densephrases/utils/embed_utils.py
#   inflating: DensePhrases-main/densephrases/utils/eval_utils.py
#   inflating: DensePhrases-main/densephrases/utils/file_utils.py
#    creating: DensePhrases-main/densephrases/utils/kilt/
#  extracting: DensePhrases-main/densephrases/utils/kilt/__init__.py
#   inflating: DensePhrases-main/densephrases/utils/kilt/eval.py
#   inflating: DensePhrases-main/densephrases/utils/kilt/kilt_utils.py
#   inflating: DensePhrases-main/densephrases/utils/open_utils.py
#   inflating: DensePhrases-main/densephrases/utils/single_utils.py
#   inflating: DensePhrases-main/densephrases/utils/squad_metrics.py
#   inflating: DensePhrases-main/densephrases/utils/squad_utils.py
#   inflating: DensePhrases-main/download.sh
#   inflating: DensePhrases-main/eval_phrase_retrieval.py
#   inflating: DensePhrases-main/generate_phrase_vecs.py
#    creating: DensePhrases-main/pic_files/
#   inflating: DensePhrases-main/pic_files/.DS_Store
#   inflating: DensePhrases-main/pic_files/faq1.jpg
#   inflating: DensePhrases-main/pic_files/faq2.jpg
#   inflating: DensePhrases-main/pic_files/step1.jpg
#   inflating: DensePhrases-main/pic_files/step1_test_a.jpg
#   inflating: DensePhrases-main/pic_files/step1_test_q.jpg
#   inflating: DensePhrases-main/pic_files/web_demo.jpg
#   inflating: DensePhrases-main/requirements.txt
#   inflating: DensePhrases-main/run_demo.py
#    creating: DensePhrases-main/sample/
#   inflating: DensePhrases-main/sample/articles.json
#   inflating: DensePhrases-main/sample/questions.json
#    creating: DensePhrases-main/scripts/
#    creating: DensePhrases-main/scripts/benchmark/
#   inflating: DensePhrases-main/scripts/benchmark/benchmark_hdf5.py
#   inflating: DensePhrases-main/scripts/benchmark/create_benchmark_data.py
#    creating: DensePhrases-main/scripts/benchmark/data/
#   inflating: DensePhrases-main/scripts/benchmark/data/nq_1000_dev_denspi.json
#   inflating: DensePhrases-main/scripts/benchmark/data/nq_1000_dev_dpr.csv
#   inflating: DensePhrases-main/scripts/benchmark/data/nq_1000_dev_orqa.jsonl
#    creating: DensePhrases-main/scripts/dump/
#   inflating: DensePhrases-main/scripts/dump/check_dump.py
#   inflating: DensePhrases-main/scripts/dump/filter_hdf5.py
#   inflating: DensePhrases-main/scripts/dump/save_meta.py
#   inflating: DensePhrases-main/scripts/dump/split_hdf5.py
#    creating: DensePhrases-main/scripts/kilt/
#   inflating: DensePhrases-main/scripts/kilt/build_title2wikiid.py
#   inflating: DensePhrases-main/scripts/kilt/sample_kilt.py
#   inflating: DensePhrases-main/scripts/kilt/strip_pred.py
#    creating: DensePhrases-main/scripts/parallel/
#   inflating: DensePhrases-main/scripts/parallel/add_to_index.py
#   inflating: DensePhrases-main/scripts/parallel/dump_phrases.py
#    creating: DensePhrases-main/scripts/preprocess/
#   inflating: DensePhrases-main/scripts/preprocess/README.md
#   inflating: DensePhrases-main/scripts/preprocess/build_db.py
#   inflating: DensePhrases-main/scripts/preprocess/build_wikisquad.py
#   inflating: DensePhrases-main/scripts/preprocess/compress_metadata.py
#   inflating: DensePhrases-main/scripts/preprocess/concat_wikisquad.py
#   inflating: DensePhrases-main/scripts/preprocess/create_nq_reader.py
#   inflating: DensePhrases-main/scripts/preprocess/create_nq_reader_doc_wiki.py
#   inflating: DensePhrases-main/scripts/preprocess/create_nq_reader_wiki.py
#   inflating: DensePhrases-main/scripts/preprocess/create_openqa.py
#   inflating: DensePhrases-main/scripts/preprocess/create_tqa_ds.py
#   inflating: DensePhrases-main/scripts/preprocess/doc_db.py
#   inflating: DensePhrases-main/scripts/preprocess/download_wikidump.py
#   inflating: DensePhrases-main/scripts/preprocess/filter_noans.py
#   inflating: DensePhrases-main/scripts/preprocess/filter_wiki.py
#   inflating: DensePhrases-main/scripts/preprocess/merge_openqa.py
#   inflating: DensePhrases-main/scripts/preprocess/merge_singleqa.py
#   inflating: DensePhrases-main/scripts/preprocess/nq_utils.py
#   inflating: DensePhrases-main/scripts/preprocess/prep_wikipedia.py
#   inflating: DensePhrases-main/scripts/preprocess/sample_nq_reader_doc_wiki.py
#   inflating: DensePhrases-main/scripts/preprocess/simple_tokenizer.py
#   inflating: DensePhrases-main/scripts/preprocess/stat_entities.py
#    creating: DensePhrases-main/scripts/question_generation/
#   inflating: DensePhrases-main/scripts/question_generation/filter_qg.py
#   inflating: DensePhrases-main/scripts/question_generation/generate_squad.py
#   inflating: DensePhrases-main/setup.py
#   inflating: DensePhrases-main/step1_test_with_question.py
#   inflating: DensePhrases-main/train_query.py
#   inflating: DensePhrases-main/train_rc.py
#    creating: DensePhrases-main/web_demo_django/
#    creating: DensePhrases-main/web_demo_django/.idea/
#   inflating: DensePhrases-main/web_demo_django/.idea/.gitignore
#   inflating: DensePhrases-main/web_demo_django/.idea/djangoProject.iml
#    creating: DensePhrases-main/web_demo_django/.idea/inspectionProfiles/
#   inflating: DensePhrases-main/web_demo_django/.idea/inspectionProfiles/profiles_settings.xml
#   inflating: DensePhrases-main/web_demo_django/.idea/misc.xml
#   inflating: DensePhrases-main/web_demo_django/.idea/modules.xml
#   inflating: DensePhrases-main/web_demo_django/.idea/vcs.xml
#  extracting: DensePhrases-main/web_demo_django/db.sqlite3
#    creating: DensePhrases-main/web_demo_django/djangoProject/
#  extracting: DensePhrases-main/web_demo_django/djangoProject/__init__.py
#    creating: DensePhrases-main/web_demo_django/djangoProject/__pycache__/
#   inflating: DensePhrases-main/web_demo_django/djangoProject/__pycache__/__init__.cpython-37.pyc
#   inflating: DensePhrases-main/web_demo_django/djangoProject/__pycache__/settings.cpython-37.pyc
#   inflating: DensePhrases-main/web_demo_django/djangoProject/__pycache__/urls.cpython-37.pyc
#   inflating: DensePhrases-main/web_demo_django/djangoProject/__pycache__/wsgi.cpython-37.pyc
#   inflating: DensePhrases-main/web_demo_django/djangoProject/asgi.py
#   inflating: DensePhrases-main/web_demo_django/djangoProject/settings.py
#   inflating: DensePhrases-main/web_demo_django/djangoProject/urls.py
#   inflating: DensePhrases-main/web_demo_django/djangoProject/wsgi.py
#   inflating: DensePhrases-main/web_demo_django/manage.py
#    creating: DensePhrases-main/web_demo_django/static/
#   inflating: DensePhrases-main/web_demo_django/static/4765EC7C5AC21205066162EC72742A21.JPG
#    creating: DensePhrases-main/web_demo_django/static/bootstrap/
#    creating: DensePhrases-main/web_demo_django/static/bootstrap/css/
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/aa.css
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bb.css
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap-theme.css
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap-theme.css.map
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap-theme.min.css
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap-theme.min.css.map
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap.css
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap.css.map
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap.min.css
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/bootstrap.min.css.map
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/css/cc.css
#  extracting: DensePhrases-main/web_demo_django/static/bootstrap/css/dd.css
#    creating: DensePhrases-main/web_demo_django/static/bootstrap/fonts/
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/fonts/glyphicons-halflings-regular.eot
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/fonts/glyphicons-halflings-regular.svg
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/fonts/glyphicons-halflings-regular.ttf
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/fonts/glyphicons-halflings-regular.woff
#  extracting: DensePhrases-main/web_demo_django/static/bootstrap/fonts/glyphicons-halflings-regular.woff2
#    creating: DensePhrases-main/web_demo_django/static/bootstrap/js/
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/js/bootstrap.js
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/js/bootstrap.min.js
#   inflating: DensePhrases-main/web_demo_django/static/bootstrap/js/npm.js
#   inflating: DensePhrases-main/web_demo_django/static/dashboard.css
#    creating: DensePhrases-main/web_demo_django/static/fontawesome/
#    creating: DensePhrases-main/web_demo_django/static/fontawesome/css/
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/css/font-awesome.css
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/css/font-awesome.min.css
#    creating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/FontAwesome.otf
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/fontawesome-webfont.eot
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/fontawesome-webfont.svg
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/fontawesome-webfont.ttf
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/fontawesome-webfont.woff
#   inflating: DensePhrases-main/web_demo_django/static/fontawesome/fonts/fontawesome-webfont.woff2
#   inflating: DensePhrases-main/web_demo_django/static/img.png
#   inflating: DensePhrases-main/web_demo_django/static/jquery-3.3.1.js
#   inflating: DensePhrases-main/web_demo_django/static/main.css
#   inflating: DensePhrases-main/web_demo_django/static/picture.jpg
#   inflating: DensePhrases-main/web_demo_django/static/picture1.jpg
#   inflating: DensePhrases-main/web_demo_django/static/picture2.jpg
#   inflating: DensePhrases-main/web_demo_django/static/picture6.jpg
#   inflating: DensePhrases-main/web_demo_django/static/picture7.jpg
#   inflating: DensePhrases-main/web_demo_django/static/picture8.jpg
#    creating: DensePhrases-main/web_demo_django/templates/
#   inflating: DensePhrases-main/web_demo_django/templates/web1.html
#    creating: DensePhrases-main/web_demo_django/web_display/
#  extracting: DensePhrases-main/web_demo_django/web_display/__init__.py
#    creating: DensePhrases-main/web_demo_django/web_display/__pycache__/
#   inflating: DensePhrases-main/web_demo_django/web_display/__pycache__/__init__.cpython-37.pyc
#   inflating: DensePhrases-main/web_demo_django/web_display/__pycache__/views.cpython-37.pyc
#   inflating: DensePhrases-main/web_demo_django/web_display/admin.py
#   inflating: DensePhrases-main/web_demo_django/web_display/apps.py
#    creating: DensePhrases-main/web_demo_django/web_display/migrations/
#  extracting: DensePhrases-main/web_demo_django/web_display/migrations/__init__.py
#   inflating: DensePhrases-main/web_demo_django/web_display/models.py
#   inflating: DensePhrases-main/web_demo_django/web_display/tests.py
#   inflating: DensePhrases-main/web_demo_django/web_display/views.py
# /content/DensePhrases-main
# Requirement already satisfied: torch==1.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.7.1)
# Requirement already satisfied: transformers==2.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (4.62.3)
# Requirement already satisfied: blosc in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (1.10.6)
# Requirement already satisfied: ujson in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (4.2.0)
# Requirement already satisfied: rouge in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (0.12.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.1.4)
# Requirement already satisfied: flask_cors in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (3.0.10)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: requests-futures in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: django in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 14)) (3.2.8)
# Requirement already satisfied: faiss-gpu==1.6.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (1.6.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->-r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0->-r requirements.txt (line 2)) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0->-r requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0->-r requirements.txt (line 2)) (0.0.46)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0->-r requirements.txt (line 2)) (0.1.96)
# Requirement already satisfied: tokenizers==0.7.0 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->-r requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (5.4.8)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (3.1.24)
# Requirement already satisfied: yaspin>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (7.1.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (3.13)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (3.5.4)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (3.17.3)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (5.0.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb->-r requirements.txt (line 8)) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0->-r requirements.txt (line 2)) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask->-r requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->-r requirements.txt (line 10)) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: asgiref<4,>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from django->-r requirements.txt (line 14)) (3.4.1)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django->-r requirements.txt (line 14)) (0.4.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django->-r requirements.txt (line 14)) (2018.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0->-r requirements.txt (line 2)) (1.0.1)
# running develop
# running egg_info
# creating densephrases.egg-info
# writing densephrases.egg-info/PKG-INFO
# writing dependency_links to densephrases.egg-info/dependency_links.txt
# writing requirements to densephrases.egg-info/requires.txt
# writing top-level names to densephrases.egg-info/top_level.txt
# writing manifest file 'densephrases.egg-info/SOURCES.txt'
# reading manifest file 'densephrases.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'densephrases.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.7/dist-packages/densephrases.egg-link (link to .)
# Adding densephrases 1.0 to easy-install.pth file
#
# Installed /content/DensePhrases-main
# Processing dependencies for densephrases==1.0
# Searching for faiss-gpu==1.6.5
# Best match: faiss-gpu 1.6.5
# Adding faiss-gpu 1.6.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Django==3.2.8
# Best match: Django 3.2.8
# Adding Django 3.2.8 to easy-install.pth file
# Installing django-admin script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests-futures==1.0.0
# Best match: requests-futures 1.0.0
# Adding requests-futures 1.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tornado==5.1.1
# Best match: tornado 5.1.1
# Adding tornado 5.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Flask-Cors==3.0.10
# Best match: Flask-Cors 3.0.10
# Adding Flask-Cors 3.0.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Flask==1.1.4
# Best match: Flask 1.1.4
# Adding Flask 1.1.4 to easy-install.pth file
# Installing flask script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for nltk==3.2.5
# Best match: nltk 3.2.5
# Adding nltk 3.2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for wandb==0.12.4
# Best match: wandb 0.12.4
# Adding wandb 0.12.4 to easy-install.pth file
# Installing wandb script to /usr/local/bin
# Installing wb script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for rouge==1.0.1
# Best match: rouge 1.0.1
# Adding rouge 1.0.1 to easy-install.pth file
# Installing rouge script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for ujson==4.2.0
# Best match: ujson 4.2.0
# Adding ujson 4.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for blosc==1.10.6
# Best match: blosc 1.10.6
# Adding blosc 1.10.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tqdm==4.62.3
# Best match: tqdm 4.62.3
# Adding tqdm 4.62.3 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for h5py==3.1.0
# Best match: h5py 3.1.0
# Adding h5py 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for transformers==2.9.0
# Best match: transformers 2.9.0
# Adding transformers 2.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torch==1.7.1
# Best match: torch 1.7.1
# Adding torch 1.7.1 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for asgiref==3.4.1
# Best match: asgiref 3.4.1
# Adding asgiref 3.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sqlparse==0.4.2
# Best match: sqlparse 0.4.2
# Adding sqlparse 0.4.2 to easy-install.pth file
# Installing sqlformat script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Jinja2==2.11.3
# Best match: Jinja2 2.11.3
# Adding Jinja2 2.11.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Werkzeug==1.0.1
# Best match: Werkzeug 1.0.1
# Adding Werkzeug 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for itsdangerous==1.1.0
# Best match: itsdangerous 1.1.0
# Adding itsdangerous 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for click==7.1.2
# Best match: click 7.1.2
# Adding click 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for subprocess32==3.5.4
# Best match: subprocess32 3.5.4
# Adding subprocess32 3.5.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for promise==2.3
# Best match: promise 2.3
# Adding promise 2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pathtools==0.1.2
# Best match: pathtools 0.1.2
# Adding pathtools 0.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for protobuf==3.17.3
# Best match: protobuf 3.17.3
# Adding protobuf 3.17.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for psutil==5.4.8
# Best match: psutil 5.4.8
# Adding psutil 5.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for shortuuid==1.0.1
# Best match: shortuuid 1.0.1
# Adding shortuuid 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for GitPython==3.1.24
# Best match: GitPython 3.1.24
# Adding GitPython 3.1.24 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for docker-pycreds==0.4.0
# Best match: docker-pycreds 0.4.0
# Adding docker-pycreds 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for yaspin==2.1.0
# Best match: yaspin 2.1.0
# Adding yaspin 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for configparser==5.0.2
# Best match: configparser 5.0.2
# Adding configparser 5.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sentry-sdk==1.4.3
# Best match: sentry-sdk 1.4.3
# Adding sentry-sdk 1.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cached-property==1.5.2
# Best match: cached-property 1.5.2
# Adding cached-property 1.5.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tokenizers==0.7.0
# Best match: tokenizers 0.7.0
# Adding tokenizers 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sentencepiece==0.1.96
# Best match: sentencepiece 0.1.96
# Adding sentencepiece 0.1.96 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sacremoses==0.0.46
# Best match: sacremoses 0.0.46
# Adding sacremoses 0.0.46 to easy-install.pth file
# Installing sacremoses script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for regex==2019.12.20
# Best match: regex 2019.12.20
# Adding regex 2019.12.20 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for filelock==3.3.0
# Best match: filelock 3.3.0
# Adding filelock 3.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==3.7.4.3
# Best match: typing-extensions 3.7.4.3
# Adding typing-extensions 3.7.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2021.5.30
# Best match: certifi 2021.5.30
# Adding certifi 2021.5.30 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for MarkupSafe==2.0.1
# Best match: MarkupSafe 2.0.1
# Adding MarkupSafe 2.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for gitdb==4.0.7
# Best match: gitdb 4.0.7
# Adding gitdb 4.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for termcolor==1.1.0
# Best match: termcolor 1.1.0
# Adding termcolor 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for joblib==1.0.1
# Best match: joblib 1.0.1
# Adding joblib 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for smmap==4.0.0
# Best match: smmap 4.0.0
# Adding smmap 4.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for densephrases==1.0

# %% [markdown]
# 设置相关环境变量

# %%
# Running config.sh will set the following three environment variables:
# DATA_DIR: for datasets
# SAVE_DIR: for pre-trained models or index; new models and index will also be saved here
# CACHE_DIR: for cache files from huggingface transformers
# !source config.sh
# Out:
# Environment variables are set as follows:
# DATA_DIR=.//densephrases-data
# SAVE_DIR=.//outputs
# CACHE_DIR=.//cache
# Add to ~/.bashrc (recommended)? [yes/no]: yes
# --2021-10-08 11:06:39--  https://nlp.cs.princeton.edu/projects/densephrases/models/densephrases-multi.tar.gz
# Resolving nlp.cs.princeton.edu (nlp.cs.princeton.edu)... 128.112.136.61
# Connecting to nlp.cs.princeton.edu (nlp.cs.princeton.edu)|128.112.136.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1114266598 (1.0G) [application/x-gzip]
# Saving to: ‘.//outputs/densephrases-multi.tar.gz’
#
# .//outputs/densephr 100%[===================>]   1.04G  33.3MB/s    in 32s
#
# 2021-10-08 11:07:11 (33.6 MB/s) - ‘.//outputs/densephrases-multi.tar.gz’ saved [1114266598/1114266598]
#
# densephrases-multi/special_tokens_map.json
# densephrases-multi/vocab.txt
# densephrases-multi/config.json
# densephrases-multi/tokenizer_config.json
# densephrases-multi/training_args.bin
# densephrases-multi/pytorch_model.bin

# %%
import os
os.environ['DATA_DIR']='./densephrases-data'
os.environ['CACHE_DIR']='./cache'
os.environ['SAVE_DIR']='./outputs'

# %% [markdown]
# 检查一下正确性

# %%
# Check downloads
# !pip list
# Out:
# Package                       Version        Location
# ----------------------------- -------------- ------------------------------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# apex                          0.1
# appdirs                       1.4.4
# argcomplete                   1.12.3
# argon2-cffi                   21.1.0
# arviz                         0.11.4
# asgiref                       3.4.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# blosc                         1.10.6
# bokeh                         2.3.3
# Bottleneck                    1.3.2
# branca                        0.4.2
# bs4                           0.0.1
# CacheControl                  0.12.6
# cached-property               1.5.2
# cachetools                    4.2.4
# catalogue                     1.0.0
# certifi                       2021.5.30
# cffi                          1.14.6
# cftime                        1.5.1
# chardet                       3.0.4
# charset-normalizer            2.0.6
# clang                         5.0
# click                         7.1.2
# cloudpickle                   1.3.0
# cmake                         3.12.0
# cmdstanpy                     0.9.5
# colorcet                      2.0.6
# colorlover                    0.3.0
# community                     1.0.0b1
# configparser                  5.0.2
# contextlib2                   0.5.5
# convertdate                   2.3.2
# coverage                      3.7.1
# coveralls                     0.5
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda111                  9.4.0
# cvxopt                        1.2.7
# cvxpy                         1.0.31
# cycler                        0.10.0
# cymem                         2.0.5
# Cython                        0.29.24
# daft                          0.0.4
# dask                          2.12.0
# datascience                   0.10.6
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# densephrases                  1.0            /content/gdrive/My Drive/DensePhrases-main
# descartes                     1.1.0
# dill                          0.3.4
# distributed                   1.25.3
# Django                        3.2.8
# dlib                          19.18.0
# dm-tree                       0.1.6
# docker-pycreds                0.4.0
# docopt                        0.6.2
# docutils                      0.17.1
# dopamine-rl                   1.0.5
# earthengine-api               0.1.284
# easydict                      1.9
# ecos                          2.0.7.post1
# editdistance                  0.5.3
# en-core-web-sm                2.2.5
# entrypoints                   0.3
# ephem                         4.1
# et-xmlfile                    1.1.0
# fa2                           0.3.5
# faiss-gpu                     1.6.5
# fastai                        1.0.61
# fastdtw                       0.3.4
# fastprogress                  1.0.0
# fastrlock                     0.6
# fbprophet                     0.7.1
# feather-format                0.4.1
# filelock                      3.3.0
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# Flask-Cors                    3.0.10
# flatbuffers                   1.12
# folium                        0.8.3
# future                        0.16.0
# gast                          0.4.0
# GDAL                          2.2.2
# gdown                         3.6.4
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.4.0
# gitdb                         4.0.7
# GitPython                     3.1.24
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.26.3
# google-api-python-client      1.12.8
# google-auth                   1.35.0
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.0
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.53.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      1.1.2
# grpcio                        1.41.0
# gspread                       3.0.1
# gspread-dataframe             3.0.8
# gym                           0.17.3
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.2
# holidays                      0.10.5.2
# holoviews                     1.14.6
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# humanize                      0.5.1
# hyperopt                      0.1.2
# ideep4py                      2.0.0.post3
# idna                          2.10
# imageio                       2.4.1
# imagesize                     1.2.0
# imbalanced-learn              0.4.3
# imblearn                      0.0
# imgaug                        0.2.9
# importlib-metadata            4.8.1
# importlib-resources           5.2.2
# imutils                       0.5.4
# inflect                       2.1.0
# iniconfig                     1.1.1
# intel-openmp                  2021.4.0
# intervaltree                  2.1.0
# ipykernel                     4.10.1
# ipython                       5.5.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.6.5
# itsdangerous                  1.1.0
# jax                           0.2.21
# jaxlib                        0.1.71+cuda111
# jdcal                         1.4.1
# jedi                          0.18.0
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.0.1
# jpeg4py                       0.1.4
# jsonschema                    2.6.0
# jupyter                       1.0.0
# jupyter-client                5.3.5
# jupyter-console               5.2.0
# jupyter-core                  4.8.1
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.0.2
# kaggle                        1.5.12
# kapre                         0.3.5
# keras                         2.6.0
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.3.2
# korean-lunar-calendar         0.2.1
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.34.0
# lmdb                          0.99
# LunarCalendar                 0.0.9
# lxml                          4.2.6
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.2.2
# matplotlib-inline             0.1.3
# matplotlib-venn               0.11.6
# missingno                     0.5.0
# mistune                       0.8.4
# mizani                        0.6.0
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.10.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.2
# multiprocess                  0.70.12.2
# multitasking                  0.0.9
# murmurhash                    1.0.5
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.5.4
# nbconvert                     5.6.1
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# netCDF4                       1.5.7
# networkx                      2.6.3
# nibabel                       3.0.2
# nltk                          3.2.5
# notebook                      5.3.1
# numba                         0.51.2
# numexpr                       2.7.3
# numpy                         1.19.5
# nvidia-ml-py3                 7.352.0
# oauth2client                  4.1.3
# oauthlib                      3.1.1
# okgrade                       0.4.3
# opencv-contrib-python         4.1.2.30
# opencv-python                 4.1.2.30
# openpyxl                      2.5.9
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     21.0
# palettable                    3.3.0
# pandas                        1.1.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.11.1
# parso                         0.8.2
# pathlib                       1.0.1
# pathtools                     0.1.2
# patsy                         0.5.2
# pep517                        0.11.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           21.1.3
# pip-tools                     6.2.0
# plac                          1.1.3
# plotly                        4.4.1
# plotnine                      0.6.0
# pluggy                        0.7.1
# pooch                         1.5.1
# portpicker                    1.3.9
# prefetch-generator            1.0.1
# preshed                       3.0.5
# prettytable                   2.2.1
# progressbar2                  3.38.0
# prometheus-client             0.11.0
# promise                       2.3
# prompt-toolkit                1.0.18
# protobuf                      3.17.3
# psutil                        5.4.8
# psycopg2                      2.7.6.1
# ptyprocess                    0.7.0
# py                            1.10.0
# pyarrow                       3.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.2
# pycparser                     2.20
# pyct                          0.4.8
# pydata-google-auth            1.2.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0
# pyglet                        1.5.0
# Pygments                      2.6.1
# pygobject                     3.26.1
# pymc3                         3.11.4
# PyMeeus                       0.5.11
# pymongo                       3.12.0
# pymystem3                     0.2.0
# PyOpenGL                      3.1.5
# pyparsing                     2.4.7
# pyrsistent                    0.18.0
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        2.19.1.1
# pytest                        3.6.4
# python-apt                    0.0.0
# python-chess                  0.23.11
# python-dateutil               2.8.2
# python-louvain                0.15
# python-slugify                5.0.2
# python-utils                  2.5.6
# pytz                          2018.9
# pyviz-comms                   2.1.0
# PyWavelets                    1.1.1
# PyYAML                        3.13
# pyzmq                         22.3.0
# qdldl                         0.1.5.post0
# qtconsole                     5.1.1
# QtPy                          1.11.2
# regex                         2019.12.20
# requests                      2.23.0
# requests-futures              1.0.0
# requests-oauthlib             1.3.0
# resampy                       0.2.2
# retrying                      1.3.3
# rouge                         1.0.1
# rpy2                          3.4.5
# rsa                           4.7.2
# sacremoses                    0.0.46
# scikit-image                  0.16.2
# scikit-learn                  0.22.2.post1
# scipy                         1.4.1
# screen-resolution-extra       0.0.0
# scs                           2.1.4
# seaborn                       0.11.2
# semver                        2.13.0
# Send2Trash                    1.8.0
# sentencepiece                 0.1.96
# sentry-sdk                    1.4.3
# setuptools                    57.4.0
# setuptools-git                1.2
# Shapely                       1.7.1
# shortuuid                     1.0.1
# simplegeneric                 0.8.1
# six                           1.15.0
# sklearn                       0.0
# sklearn-pandas                1.8.0
# smart-open                    5.2.1
# smmap                         4.0.0
# snowballstemmer               2.1.0
# sortedcontainers              2.4.0
# SoundFile                     0.10.3.post1
# spacy                         2.2.4
# Sphinx                        1.8.5
# sphinxcontrib-serializinghtml 1.1.5
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.4.25
# sqlparse                      0.4.2
# srsly                         1.0.5
# statsmodels                   0.10.2
# subprocess32                  3.5.4
# sympy                         1.7.1
# tables                        3.4.4
# tabulate                      0.8.9
# tblib                         1.7.0
# tensorboard                   2.6.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.6.0
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.6.0
# tensorflow-gcs-config         2.6.0
# tensorflow-hub                0.12.0
# tensorflow-metadata           1.2.0
# tensorflow-probability        0.14.1
# termcolor                     1.1.0
# terminado                     0.12.1
# testpath                      0.5.0
# text-unidecode                1.3
# textblob                      0.15.3
# Theano-PyMC                   1.1.2
# thinc                         7.4.0
# tifffile                      2021.8.30
# tokenizers                    0.7.0
# toml                          0.10.2
# tomli                         1.2.1
# toolz                         0.11.1
# torch                         1.7.1
# torchsummary                  1.5.1
# torchtext                     0.10.0
# torchvision                   0.10.0+cu111
# tornado                       5.1.1
# tqdm                          4.62.3
# traitlets                     5.1.0
# transformers                  2.9.0
# tweepy                        3.10.0
# typeguard                     2.7.1
# typing-extensions             3.7.4.3
# tzlocal                       1.5.1
# ujson                         4.2.0
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wandb                         0.12.4
# wasabi                        0.8.2
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.37.0
# widgetsnbextension            3.5.1
# wordcloud                     1.5.0
# wrapt                         1.12.1
# xarray                        0.18.2
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yaspin                        2.1.0
# yellowbrick                   0.9.1
# zict                          2.0.0
# zipp                          3.6.0

# %% [markdown]
# ## 训练Demo
# 运行以下命令，生成模型Demo

# %%
# generate phrase vectors
# build phrase index
# evaluate phrase retrieval
# (try it more times if something goes wrong.)
# !make step1

# %% [markdown]
# ## 测试Demo
# 通过命令台输入测试Demo模型。

# %%
# evaluate phrase retrieval with input question
# output the answer, but write details in 'sample/step1_question_test_out.json'

# !make step1_test
# Out:
# python step1_test_with_question.py \
# 	--dump_dir ./outputs/densephrases-physics/dump \
#     	--index_dir start/32_flat_OPQ96 \
#     	--query_encoder_path ./outputs/densephrases-multi
# 10/08/2021 11:10:30 - INFO - densephrases.utils.file_utils -   PyTorch version 1.7.1 available.
# 10/08/2021 11:10:30 - INFO - densephrases.utils.file_utils -   TensorFlow version 2.6.0 available.
# just input what you want to ask (relevant to the sample articles) :
# what is polarization?
# Query encoder will be loaded from ./outputs/densephrases-multi
# 10/08/2021 11:10:44 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/SpanBERT/spanbert-base-cased/config.json from cache at /root/.cache/torch/transformers/f657841af52c33ad17850f7918b10fbfc48e447d49d35bee4081df30d7b54545.e736d0f2e9459c34485cfbdd4c15e2b18d74c1c4359ee99166a419eaaab2994b
# 10/08/2021 11:10:44 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }
#
# 10/08/2021 11:10:45 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/SpanBERT/spanbert-base-cased/config.json from cache at /root/.cache/torch/transformers/f657841af52c33ad17850f7918b10fbfc48e447d49d35bee4081df30d7b54545.e736d0f2e9459c34485cfbdd4c15e2b18d74c1c4359ee99166a419eaaab2994b
# 10/08/2021 11:10:45 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }
#
# 10/08/2021 11:10:45 - INFO - transformers.tokenization_utils -   Model name 'SpanBERT/spanbert-base-cased' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'SpanBERT/spanbert-base-cased' is a path, a model identifier, or url to a directory containing tokenizer files.
# 10/08/2021 11:10:46 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/SpanBERT/spanbert-base-cased/vocab.txt from cache at /root/.cache/torch/transformers/450d2ca167544c8b0b1363bd390701766966fb14a0a03531c76a7e8ea8231d6b.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# 10/08/2021 11:10:46 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/SpanBERT/spanbert-base-cased/added_tokens.json from cache at None
# 10/08/2021 11:10:46 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/SpanBERT/spanbert-base-cased/special_tokens_map.json from cache at None
# 10/08/2021 11:10:46 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/SpanBERT/spanbert-base-cased/tokenizer_config.json from cache at None
# 10/08/2021 11:10:46 - INFO - densephrases.models.encoder -   Pre-trained DensePhrases must be loaded
# 10/08/2021 11:10:52 - INFO - densephrases.utils.open_utils -   DensePhrases loaded from ./outputs/densephrases-multi having <class 'transformers.modeling_bert.BertModel'>
# 10/08/2021 11:10:52 - INFO - densephrases.utils.open_utils -   Number of model parameters: 324,932,354
#   0% 0/1 [00:00<?, ?it/s]['what is polarization?']
# 100% 1/1 [00:00<00:00,  1.91it/s]
# 10/08/2021 11:10:52 - INFO - densephrases.utils.open_utils -   Aggregate: False
# 10/08/2021 11:10:52 - INFO - densephrases.models.index -   Reading ./outputs/densephrases-physics/dump/start/32_flat_OPQ96/index.faiss
# 10/08/2021 11:10:52 - INFO - densephrases.models.index -   index ntotal: 2507 | PQ: True
# 10/08/2021 11:10:52 - INFO - densephrases.models.index -   Load idx2id on memory
# loading idx2id: 100% 1/1 [00:00<00:00, 334.37it/s]
# 10/08/2021 11:10:53 - INFO - densephrases.models.index -   Loading metadata on RAM from ./outputs/densephrases-physics/dump/meta_compressed.pkl (for PQ only)
# 100% 1/1 [00:00<00:00, 56.60it/s]
#
# ############### Answer: ################
# alignment of the electric vectors that make up electromagnetic radiation

# %% [markdown]
# 进一步地，通过运行`web_demo_django`文件夹下或者自己编写的网页演示程序来将模型封装，进行交互式的输入输出
#
# 需将训练好的模型copy至本地再运行Django，具体可以项目Readme

# %% [markdown]
# ## Reference
# Please cite the paper if you use DensePhrases in your work:
# ```bibtex
# @inproceedings{lee2021learning,
#    title={Learning Dense Representations of Phrases at Scale},
#    author={Lee, Jinhyuk and Sung, Mujeen and Kang, Jaewoo and Chen, Danqi},
#    booktitle={Association for Computational Linguistics (ACL)},
#    year={2021}
# }
# ```
#
# ## License
# Please see LICENSE for details.
#
# [demo]: http://densephrases.korea.ac.kr
